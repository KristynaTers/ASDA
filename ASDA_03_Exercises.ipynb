# %% [markdown]
# # Loading & Visualising Financial Data — Exercises
# ### Applied Statistical Data Analysis — Prof. Dr. Kristyna Ters | MSc Finance | FHNW
#
# ---
# > **Instructions:**
# > - Work through the exercises in order
# > - Fill in your code in the empty cells marked with `# YOUR CODE HERE`
# > - Answer written questions by double-clicking the markdown cell and editing it
# > - Run cells with **Shift+Enter**
# > - Solutions will be released after the submission deadline

# %%
# !pip install yfinance pandas-datareader seaborn --quiet

import yfinance as yf
import pandas_datareader.data as web
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# FHNW corporate palette
YELLOW = '#FDE70E'; ORANGE = '#FCB310'; RED = '#C70101'
GREY   = '#4B4B4B'; BLUE = '#0E75FE'

# Global plotting defaults — apply once, every chart benefits
plt.rcParams.update({
    'figure.facecolor':'white', 'axes.facecolor':'white',
    'axes.spines.top':False, 'axes.spines.right':False,
    'axes.grid':True, 'grid.alpha':0.25, 'font.size':11,
})
print('✓ Libraries loaded.')

# %% [markdown]
# ---
# # Exercise 1 — Match the Data Source
#
# For each task, state which Python library you would use (yfinance, pandas-datareader, wbgapi).
#
# | # | Task | Library |
# |---|------|---------|
# | a | Download Tesla daily prices for 2023 | |
# | b | Get the US 10-year Treasury yield since 2010 | |
# | c | Compare the EUR/USD exchange rate to the CHF/USD rate (daily) | |
# | d | Pull Switzerland's GDP per capita 1990–2023 | |
# | e | Download Bitcoin daily prices for 2024 | |
# | f | Get the US Consumer Price Index (CPI), monthly | |
#
# **Your answers** (double-click to edit):
#
# | # | Library |
# |---|---------|
# | a | |
# | b | |
# | c | |
# | d | |
# | e | |
# | f | |

# %% [markdown]
# ---
# # Exercise 2 — Download & Inspect a Swiss Stock
#
# Pick a Swiss blue-chip (`NESN.SW`, `NOVN.SW`, `ROG.SW`, `UBSG.SW`, …) and run a full inspection.

# %%
# YOUR CODE HERE
# 1. Download your stock for 2019-01-01 to 2024-12-31 with auto_adjust=True
# 2. Print: number of rows, date range, shape
# 3. Run head(), info(), and isnull().sum()
# 4. Make a quick price plot

# %% [markdown]
# **Questions:**
# 1. How many trading days does your Swiss stock have over the period? Compare to ~252/year × 6 years for a US stock
# 2. Are there any missing values? Why might that be?
# 3. What is the currency of the prices? (Hint: `yfinance` follows the listing exchange)
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 3 — Macro Data from FRED
#
# Use `pandas-datareader` to download three FRED series and visualise them on a single chart.

# %%
# YOUR CODE HERE
# 1. Download three FRED series for 2010-01-01 to today:
#    - 'DGS10'    : 10-year Treasury yield
#    - 'DGS2'     : 2-year Treasury yield
#    - 'MORTGAGE30US' : 30-year fixed mortgage rate
# 2. Combine them into one DataFrame (concat or merge on the date index)
# 3. Plot all three on the same axis with different colors
# 4. Use a legend OUTSIDE the plot area, label the y-axis 'Rate (%)'

# %% [markdown]
# **Questions:**
# 1. What is the typical spread between the 30-year mortgage rate and the 10-year Treasury yield?
# 2. When does the 2-year yield rise *above* the 10-year (yield curve inversion)? Why is this often discussed as a recession signal?
# 3. Why do all three series move broadly together?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 4 — Cleaning a Multi-Asset Panel
#
# Different markets, different calendars. Quantify the mess.

# %%
# YOUR CODE HERE
# 1. Download a 1-year window (2023) for: 'AAPL', 'NESN.SW', 'BTC-USD', 'EURUSD=X'
# 2. Extract the 'Close' panel
# 3. Print, for each ticker: how many trading days? how many NaNs?
# 4. Apply two cleaning strategies and compare:
#    a) prices.dropna()                  — strict intersection
#    b) prices.ffill().dropna()           — forward-fill then drop
#    Print the resulting row count for each

# %% [markdown]
# **Questions:**
# 1. Which asset has the most observations in 2023? Why?
# 2. After `dropna()`, how many days do you have left? What's the bottleneck?
# 3. When would you prefer forward-fill over strict drop? Give a concrete example.
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 5 — Style Transformation: Default → Publication
#
# Apply the five styling tricks from Part 4 to a chart of your choice.

# %%
# YOUR CODE HERE
# 1. Pick any 2 stocks (your choice). Download 2019-01-01 to 2024-12-31.
# 2. First, plot the two close-price series with default matplotlib styling
#    (set spines on, no annotation, default legend, generic title)
# 3. Then, in a SECOND cell, plot them again applying the five tricks:
#    - spines off
#    - brand palette (2 colors max from {black, ORANGE, RED, BLUE})
#    - left-aligned title with units in y-label
#    - annotate ONE event of your choice (e.g. COVID, Fed meeting, earnings)
#    - legend OUTSIDE the plot area

# %% [markdown]
# **Questions:**
# 1. In your default plot, did the legend cover any data? If yes, where?
# 2. What event did you annotate, and why?
# 3. Of the five tricks, which one improves readability the most for *your* specific chart?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 6 — Multi-Asset Comparison with COVID Annotation
#
# Build a chart comparing how different asset classes weathered the COVID crash.

# %%
# YOUR CODE HERE
# 1. Download for 2019-06-01 to 2021-06-01:
#    - SPY  (US equities)
#    - TLT  (long-term Treasuries)
#    - GLD  (gold)
#    - BTC-USD (Bitcoin)
# 2. For each, compute cumulative returns from the first available date
# 3. Plot all four on one chart, normalised to start at 0%
# 4. Highlight the COVID crash window (2020-02-20 to 2020-04-30) using ax.axvspan
# 5. Annotate the date of the worst single day for SPY
# 6. Apply publication-quality styling (legend outside!)

# %% [markdown]
# **Questions:**
# 1. Which asset suffered the largest peak-to-trough drawdown during the COVID window?
# 2. Which asset *gained* during the crash, if any?
# 3. How long did it take SPY to recover to its pre-crash level?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 7 — Build Your Own `load_panel()`
#
# Re-implement the helper function from Part 5, but extend it: also return cumulative returns and let the caller choose between simple and log returns.

# %%
# YOUR CODE HERE
def load_panel_v2(tickers, start, end, return_type='simple'):
    """Returns a tuple: (daily_returns_df, cumulative_returns_df).
    return_type: 'simple' uses pct_change(); 'log' uses np.log(p/p.shift()).
    """
    # 1. Validate return_type ∈ {'simple', 'log'}
    # 2. Download with yfinance, auto_adjust=True, progress=False
    # 3. Extract Close, drop fully-empty rows
    # 4. Compute returns according to return_type
    # 5. Compute cumulative returns:
    #    - simple → (1+r).cumprod() - 1
    #    - log    → r.cumsum()
    # 6. Return both
    pass

# Test your function:
# ret_s, cum_s = load_panel_v2(['AAPL','MSFT'], '2023-01-01', '2024-12-31', 'simple')
# ret_l, cum_l = load_panel_v2(['AAPL','MSFT'], '2023-01-01', '2024-12-31', 'log')
# print('Simple cumulative final:', cum_s.iloc[-1].round(4).to_dict())
# print('Log cumulative final:   ', cum_l.iloc[-1].round(4).to_dict())

# %% [markdown]
# **Questions:**
# 1. For your test tickers, how close are the simple-cumulative and log-cumulative final values?
# 2. When would a downstream user want log returns rather than simple?
# 3. What edge case did you need to handle in your validation step?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 8 — Save & Reload — Avoid Re-Downloading
#
# Downloading data over the internet is slow and unreliable. For any non-trivial analysis, save your cleaned DataFrame locally and reload it.

# %%
# YOUR CODE HERE
# 1. Download AAPL 2019-2024 prices, extract the Close series
# 2. Save to CSV: aapl.to_csv('aapl_prices.csv')
# 3. Reload from CSV: pd.read_csv('aapl_prices.csv', index_col=0, parse_dates=True)
# 4. Verify: shape and dtypes match the original
# 5. Time both operations (download vs reload) using time.time() — print the speed-up

# %% [markdown]
# **Questions:**
# 1. By how much does reloading from CSV speed things up vs. re-downloading?
# 2. What other formats could you use? (Hint: .parquet, .feather)
# 3. Why is `parse_dates=True` important when reloading?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 9 — Currency Mix: Returns vs. Prices
#
# Demonstrate why combining prices in different currencies is meaningless.

# %%
# YOUR CODE HERE
# 1. Download AAPL (USD) and NESN.SW (CHF) for 2023.
# 2. Bad: plot both close-PRICE series on the same y-axis. Comment on what's wrong.
# 3. Good: plot both daily-RETURN series (or cumulative returns from start of period)
#    on the same y-axis. Comment on why this works.
# 4. Bonus: download the CHF/USD FX rate from FRED ('DEXSZUS') and convert NESN.SW
#    prices to USD. Re-plot both prices in USD — does the comparison now make sense?

# %% [markdown]
# **Questions:**
# 1. Why is it nonsensical to compare a USD price to a CHF price directly?
# 2. Why does combining returns work fine even with mixed currencies?
# 3. When would you want to convert prices to a common currency vs. just using returns?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 10 — Build Your Own Mini-Dashboard
#
# Combine everything: pick a theme, build a 4-asset panel, and produce a publication-quality dashboard chart with a summary table.

# %%
# YOUR CODE HERE
# 1. Pick a theme: 'Swiss blue chips' OR 'Tech giants' OR 'Defensives' OR 'Crypto'
#    Choose 4 tickers that fit your theme.
# 2. Use load_panel() (or your v2) to get returns 2020-01-01 to 2024-12-31
# 3. Compute cumulative returns and plot them (publication quality)
# 4. Print a summary table with: total return, annualised vol, worst day, best day
# 5. Write a 2-3 sentence narrative interpreting your dashboard

# %% [markdown]
# **Your narrative** (2-3 sentences interpreting your dashboard):

# %% [markdown]
# ---
# # 🔥 Challenge — yfinance + FRED Together
#
# Combine equity and macro data in a single analysis: relate the S&P 500 to interest rates.

# %%
# YOUR CODE HERE
# 1. Download from yfinance: ^GSPC daily close 2010-01-01 to today
# 2. Download from FRED:    DGS10 (10-year Treasury yield) for the same window
# 3. Align the two series on common dates (intersection of indices)
# 4. Plot them on a SINGLE chart with TWO y-axes (twinx):
#    - Left axis: ^GSPC level (black)
#    - Right axis: 10y yield (red)
#    - Legend OUTSIDE the plot, labels for both series
# 5. Compute the correlation between daily SP500 *returns* and daily *yield changes*

# %% [markdown]
# ---
# *Applied Statistical Data Analysis | Prof. Dr. Kristyna Ters | FHNW School of Business | HS 2026*
#
# *Solutions will be released after the submission deadline.*
