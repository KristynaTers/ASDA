# %% [markdown]
# # Statistical Properties of Financial Data — Exercises
# ### Applied Statistical Data Analysis — Prof. Dr. Kristyna Ters | MSc Finance | FHNW
#
# ---
# > **Instructions:**
# > - Work through the exercises in order
# > - Fill in your code in the empty cells marked with `# YOUR CODE HERE`
# > - Answer written questions by double-clicking the markdown cell and editing it
# > - Run cells with **Shift+Enter**
# > - Solutions will be released after the submission deadline

# %%
# !pip install yfinance seaborn statsmodels --quiet
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.graphics.tsaplots as tsaplots
import warnings; warnings.filterwarnings('ignore')

plt.rcParams.update({'figure.facecolor':'white','axes.facecolor':'white',
    'axes.spines.top':False,'axes.spines.right':False,'axes.grid':True,'grid.alpha':0.3})
YELLOW='#FDE70E'; ORANGE='#FCB310'; RED='#C70101'; GREY='#4B4B4B'
print('✓ Ready.')

# %% [markdown]
# ---
# # Exercise 1 — Conceptual: Match the Statistic
#
# Match each finance question on the left with the statistic that best answers it on the right.
#
# | # | Question | Statistic |
# |---|----------|-----------|
# | a | What is the typical daily move? | |
# | b | How spread out are returns around their typical value? | |
# | c | Are losses bigger than gains on average? | |
# | d | How often do extreme moves occur compared to a Normal? | |
# | e | Is the return distribution Normal? | |
# | f | What is the worst day in the sample? | |
#
# **Choices:** Mean, Std deviation, Skewness, Excess kurtosis, Jarque-Bera p-value, Min
#
# **Your answers** (double-click to edit):
#
# | # | Statistic |
# |---|-----------|
# | a | |
# | b | |
# | c | |
# | d | |
# | e | |
# | f | |

# %% [markdown]
# ---
# # Exercise 2 — Descriptive Statistics for a Swiss Stock
#
# Choose a Swiss stock (`NESN.SW`, `NOVN.SW`, or `ROG.SW`) and produce a full descriptive summary.

# %%
# YOUR CODE HERE
# 1. Set ticker, START='2019-01-01', END='2024-12-31'
# 2. Download price data with yfinance
# 3. Compute daily returns in % (pct_change * 100)
# 4. Print ret.describe() rounded to 4 decimals
# 5. Print skewness and excess kurtosis

# %% [markdown]
# **Questions:**
# 1. What is the mean daily return? Annualised?
# 2. What is the daily and annualised volatility?
# 3. Is the skewness positive or negative? What does that mean?
# 4. Is the excess kurtosis large? What does that imply about extreme moves?
#
# **Your answers:**
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
# # Exercise 3 — Annualisation by Hand
#
# Compute annualised statistics manually for the scenarios below, then verify with Python where applicable.

# %%
# Scenario A: daily mean = 0.04%, daily std = 1.1% (typical S&P 500)
# YOUR CODE HERE
# ann_mean_A = ...
# ann_vol_A  = ...
# print(...)

# Scenario B: daily mean = 0.10%, daily std = 2.5% (typical TSLA)
# YOUR CODE HERE

# Scenario C: monthly std = 4%.  What is the annual vol?  (Hint: 12 months/year)
# YOUR CODE HERE

# %% [markdown]
# **Questions:**
# 1. Why do we use √252 for daily vol but √12 for monthly vol?
# 2. If a stock has annual vol of 32%, what is its approximate daily vol?
# 3. Under what assumption is the √T scaling rule valid? When does it break down?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 4 — Skewness & Kurtosis Across Assets
#
# Download a panel of assets and compare their higher moments.

# %%
tickers_ex4 = ['SPY', 'TLT', 'GLD', 'BTC-USD']  # equities, bonds, gold, crypto

# YOUR CODE HERE
# 1. Download all four for 2019-01-01 to 2024-12-31
# 2. Compute daily returns in %
# 3. For each: print Mean, Std, Skewness, Excess Kurtosis, Min, Max
# 4. Build a clean comparison DataFrame

# %% [markdown]
# **Questions:**
# 1. Which asset has the most negative skewness? What does this say about its risk?
# 2. Which asset has the highest excess kurtosis? Does this match your intuition?
# 3. Which asset would be the worst to model with a Normal distribution? Why?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 5 — Jarque-Bera Test on Multiple Assets
#
# Run the Jarque-Bera test on each asset from Exercise 4 and decide whether to reject normality at the 5% level.

# %%
# YOUR CODE HERE
# 1. For each asset, run stats.jarque_bera(ret)
# 2. Print: asset, JB statistic, p-value, decision (Reject / Fail to reject)
# 3. Format as a clean table

# %% [markdown]
# **Questions:**
# 1. For which assets do you reject H₀ (normality)?
# 2. What does a p-value of 1e-50 mean intuitively?
# 3. Why does this matter for VaR (Value-at-Risk) models that assume Normality?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 6 — Histogram vs. Normal: Visualise the Fat Tails
#
# Plot the empirical return distribution against a fitted Normal for one asset of your choice. Use both linear and log scales.

# %%
# YOUR CODE HERE
# 1. Pick one asset (e.g. 'AAPL' or 'BTC-USD')
# 2. Compute daily returns in %
# 3. Compute mu, sigma
# 4. Plot histogram (density=True) + Normal pdf — twice, side by side
#    Left: linear y-axis | Right: log y-axis
# 5. Annotate the worst day: how many sigma is it?

# %% [markdown]
# **Questions:**
# 1. On the linear scale, what looks 'wrong' near the centre vs. the Normal?
# 2. On the log scale, where do you see the deviation most clearly?
# 3. How many standard deviations is the worst day in your sample?
# 4. Under a Normal model, how often should that move occur? Compare to reality.
#
# **Your answers:**
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
# # Exercise 7 — Q-Q Plot Interpretation
#
# Create a Q-Q plot for a single asset and interpret its shape.

# %%
# YOUR CODE HERE
# 1. Pick one asset
# 2. Use stats.probplot(ret, dist='norm', plot=ax)
# 3. Compare side-by-side with a simulated Normal of the same length
#    (use np.random.seed(42))

# %% [markdown]
# **Questions:**
# 1. Where do the points deviate most from the red reference line?
# 2. What does this deviation tell you about the tails (fat? thin? symmetric?)
# 3. How does the simulated Normal Q-Q plot look in comparison?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 8 — Volatility Clustering Visualisation
#
# Pick any stock and create the classic 2-panel plot (price + daily returns) that makes volatility clustering visible.

# %%
# YOUR CODE HERE
# 1. Pick a stock, download 2019-2024
# 2. Two-panel plot: price (top) + daily returns bar chart (bottom)
# 3. Use sharex=True and gridspec_kw={'height_ratios':[2,1]}
# 4. Colour negative returns red and positive black
# 5. Highlight one volatile period with axvspan

# %% [markdown]
# **Questions:**
# 1. Identify two periods where large moves cluster.
# 2. Identify one period of unusual calm.
# 3. In your own words, why is volatility clustering inconsistent with i.i.d. (independent and identically distributed) returns?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 9 — ACF: Returns vs. Squared Returns
#
# Demonstrate the two key stylized facts about autocorrelation.

# %%
# YOUR CODE HERE
# 1. Pick one asset (e.g. AAPL)
# 2. Side-by-side ACF plots (lags=30):
#    Left:  ACF of returns       — should be ~ zero
#    Right: ACF of squared returns — should be high & persistent
# 3. Use the same y-axis limits on both for fair visual comparison

# %% [markdown]
# **Questions:**
# 1. Are most ACF spikes for returns inside the blue confidence band?
# 2. Are the ACF spikes for squared returns inside or outside the band?
# 3. What model class is motivated by this empirical pattern?
# 4. In one sentence: what is the practical message of these two plots together?
#
# **Your answers:**
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
# # Exercise 10 — Crisis vs. Normal Correlations
#
# Compute the correlation matrix in the COVID crash window (Feb–May 2020) and in a calm year (2021), and quantify the difference.

# %%
tickers_ex10 = ['AAPL', 'MSFT', 'JPM', 'XOM', '^GSPC']

# YOUR CODE HERE
# 1. Download all five for 2019-2024 and build ret_panel
# 2. Slice for crisis: '2020-02-01' to '2020-05-31'
# 3. Slice for normal: '2021-01-01' to '2021-12-31'
# 4. Compute correlation matrix for each
# 5. Plot side-by-side heatmaps (sns.heatmap, cmap='RdYlGn_r', center=0)
# 6. Compute and print the average off-diagonal correlation for each period

# %% [markdown]
# **Questions:**
# 1. By how much does the average correlation rise from normal to crisis?
# 2. Which pair shows the largest jump?
# 3. Why does this matter for portfolio diversification when it matters most?
# 4. What is this empirical regularity called?
#
# **Your answers:**
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
# # 🔥 Challenge — Rolling Correlation & Stylized Facts in Crypto
#
# **Challenge A:** Compute and plot a 60-day **rolling correlation** between AAPL and the S&P 500. Mark the COVID period.
#
# **Challenge B:** Run a full stylized-facts checklist on **Bitcoin** (`BTC-USD`) and compare against the S&P 500: skewness, kurtosis, JB test, ACF of $r^2$, and rolling vol.

# %%
# Challenge A: Rolling correlation
# WINDOW = 60
# YOUR CODE HERE

# %%
# Challenge B: Stylized facts — Bitcoin vs. S&P 500
# YOUR CODE HERE

# %% [markdown]
# ---
# *Applied Statistical Data Analysis | Prof. Dr. Kristyna Ters | FHNW School of Business | HS 2026*
#
# *Solutions will be released after the submission deadline.*
