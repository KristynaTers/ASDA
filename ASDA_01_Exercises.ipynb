# %% [markdown]
# # Data Types in Finance — Exercises
# ### Applied Statistical Data Analysis — Prof. Dr. Kristyna Ters | MSc Finance | FHNW
#
# ---
# > **Instructions:**
# > - Work through the exercises in order
# > - Fill in your code in the empty cells marked with `# YOUR CODE HERE`
# > - Answer written questions by double-clicking the markdown cell and editing it
# > - Run cells with **Shift+Enter**
# > - Solutions will be released after the submission deadline

# %%
# !pip install yfinance seaborn --quiet
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings; warnings.filterwarnings('ignore')

plt.rcParams.update({'figure.facecolor':'white','axes.facecolor':'white',
    'axes.spines.top':False,'axes.spines.right':False,'axes.grid':True,'grid.alpha':0.3})
YELLOW='#FDE70E'; ORANGE='#FCB310'; RED='#C70101'; GREY='#4B4B4B'
print('✓ Ready.')

# %% [markdown]
# ---
# # Exercise 1 — Identify the Data Type
#
# For each dataset, state whether it is **time series**, **cross-sectional**, or **panel** data. Justify in one sentence.
#
# | # | Dataset | Data Type | Justification |
# |---|---------|-----------|---------------|
# | a | Daily EUR/USD exchange rate, Jan 2015–Dec 2024 | | |
# | b | P/E ratios of 50 S&P 500 firms on 31 Dec 2023 | | |
# | c | Quarterly revenue of Apple, Microsoft, Google 2018–2024 | | |
# | d | Beta of Nestlé estimated using monthly returns 2010–2020 | | |
# | e | Credit ratings of 200 European banks in Q1 2024 | | |
# | f | Monthly returns of the SMI index, 2000–2024 | | |
#
# **Your answers:** (double-click to edit)
#
# | # | Data Type | Justification |
# |---|-----------|---------------|
# | a | | |
# | b | | |
# | c | | |
# | d | | |
# | e | | |
# | f | | |

# %% [markdown]
# ---
# # Exercise 2 — Download and Explore a Swiss Stock
#
# Choose a Swiss stock (`NESN.SW`, `NOVN.SW`, or `ROG.SW`) and answer the questions below.

# %%
# YOUR CODE HERE
# 1. Set ticker, start, end
# 2. Download price data with yfinance
# 3. Compute daily returns
# 4. Print: number of days, worst day (date + return), best day, std deviation
# 5. Plot: price series + daily returns (2 panels, sharex=True)

# %% [markdown]
# **Questions** (double-click to edit):
# 1. On what date was the worst single day, and what might have caused it?
# 2. How does the std deviation compare to AAPL (~1.5% daily)?
# 3. Was the mean daily return positive? What does this mean economically?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 3 — Simple vs. Log Returns: Manual Calculation
#
# Compute simple and log returns for each scenario, then verify with Python.

# %%
# Scenario A: Small move — $100 → $101
P0_a, P1_a = 100, 101
# YOUR CODE HERE
# simple_a = ...
# log_a    = ...
# print(f'A: Simple={simple_a*100:.4f}%  Log={log_a*100:.4f}%  Diff={abs(simple_a-log_a)*100:.6f}%')

# Scenario B: Large positive move — $100 → $150
P0_b, P1_b = 100, 150
# YOUR CODE HERE

# Scenario C: Large negative move (crash) — $100 → $65
P0_c, P1_c = 100, 65
# YOUR CODE HERE

# Scenario D: Round trip — $100 → $80 → $100
# Show that log returns add to 0, simple returns do not
P0_d, P1_d, P2_d = 100, 80, 100
# YOUR CODE HERE
# total_simple = (1+simple_d1)*(1+simple_d2) - 1
# total_log    = log_d1 + log_d2

# %% [markdown]
# **Questions:**
# 1. In which scenario is the difference between simple and log return largest? Why?
# 2. What property of log returns does Scenario D demonstrate?
#
# **Your answers:**
# 1.
# 2.

# %% [markdown]
# ---
# # Exercise 4 — Annualise Returns and Compute Sharpe Ratio
#
# Download AAPL (2019–2024) and compute annualised statistics.

# %%
TRADING_DAYS = 252
RISK_FREE    = 0.04  # 4% annual risk-free rate

# YOUR CODE HERE
# 1. Download AAPL 2019-2024
# 2. Compute daily simple returns
# 3. ann_return = (1 + daily_mean) ** 252 - 1
# 4. ann_vol    = daily_std * sqrt(252)
# 5. sharpe     = (ann_return - RISK_FREE) / ann_vol
# 6. Print all three with clear labels

# %% [markdown]
# **Questions:**
# 1. Is a Sharpe ratio of 1.0 considered good or bad? What is the industry benchmark?
# 2. How would the Sharpe ratio change if the risk-free rate rose to 5%?
#
# **Your answers:**
# 1.
# 2.

# %% [markdown]
# ---
# # Exercise 5 — COVID Crash Analysis
#
# Zoom into the COVID crash period (Feb–Apr 2020) for AAPL.

# %%
# YOUR CODE HERE
# 1. Filter prices for '2020-01-01' to '2020-06-30'
# 2. Find: date of worst single day and its return
# 3. Calculate peak-to-trough drawdown in %
# 4. Calculate number of days from peak to trough
# 5. Plot the price series for this period

# %% [markdown]
# **Questions:**
# 1. How many calendar days did it take from peak to trough?
# 2. What was the maximum drawdown in percent?
# 3. How does the worst single day compare to a 'normal' daily move (std deviation)? How many standard deviations was it?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 6 — Beta Estimation
#
# Download AAPL, MSFT, JPM, and S&P 500 (2019–2024). Estimate beta for each stock.

# %%
# YOUR CODE HERE
# 1. Download ['AAPL','MSFT','JPM','^GSPC']
# 2. Compute daily returns
# 3. For each stock, run stats.linregress(sp500_ret, stock_ret)
# 4. Print: Beta, Alpha, R² for each stock in a clean table

# %% [markdown]
# **Questions:**
# 1. If the S&P 500 drops 2% today, how much would you expect each stock to drop?
# 2. Which stock is most defensive? Does this make economic sense?
# 3. What does R² = 0.63 mean in plain English?
#
# **Your answers:**
# 1. AAPL: , MSFT: , JPM:
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 7 — Beta for Your Own Stock
#
# Choose any stock, estimate its beta vs. the S&P 500, and create a scatter plot with the regression line.

# %%
MY_STOCK = 'TSLA'  # change this!

# YOUR CODE HERE
# 1. Download MY_STOCK and ^GSPC
# 2. Align the return series
# 3. Estimate beta with stats.linregress
# 4. Create scatter plot: x = SP500 returns, y = stock returns
# 5. Add regression line to the plot
# 6. Label axes and add beta + R² to the legend

# %% [markdown]
# **Questions:**
# 1. Is your stock aggressive (β > 1) or defensive (β < 1)?
# 2. What does the scatter around the regression line represent?
# 3. Would you classify this as time series, cross-sectional, or panel data?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 8 — Correlation Matrix
#
# Using the panel data from Exercise 6, compute and visualise the correlation matrix.

# %%
# YOUR CODE HERE
# 1. Compute correlation matrix of ret_panel
# 2. Print the matrix rounded to 3 decimals
# 3. Plot as heatmap with seaborn (cmap='coolwarm', annot=True)

# %% [markdown]
# **Questions:**
# 1. Which two stocks are most correlated? Why economically?
# 2. Which stock offers the best diversification benefit when combined with AAPL?
# 3. Why is the diagonal always 1.0?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 9 — Crisis vs. Normal Correlations
#
# Compare correlations during the COVID crisis (Feb–May 2020) vs. a normal period (2021).

# %%
# YOUR CODE HERE
# 1. Filter ret_panel for crisis period: '2020-02-01' to '2020-05-31'
# 2. Filter ret_panel for normal period: '2021-01-01' to '2021-12-31'
# 3. Compute correlation matrix for each period
# 4. Plot side-by-side heatmaps
# 5. Print the average off-diagonal correlation for each period

# %% [markdown]
# **Questions:**
# 1. Are correlations higher or lower during the COVID crisis? By how much?
# 2. What does this imply for portfolio diversification during a crisis?
# 3. This phenomenon has a name — what is it called? (hint: Google 'correlation breakdown crisis')
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # Exercise 10 — Build an Equally-Weighted Portfolio
#
# Construct an equally-weighted portfolio of AAPL, MSFT, JPM and compare to the S&P 500.

# %%
stocks  = ['AAPL', 'MSFT', 'JPM']
weights = np.array([1/3, 1/3, 1/3])

# YOUR CODE HERE
# 1. Compute portfolio daily returns: (ret_panel[stocks] * weights).sum(axis=1)
# 2. Compute cumulative returns for portfolio and S&P 500
# 3. Plot both on same chart
# 4. Compute and print: ann. return, ann. vol, Sharpe for both

# %% [markdown]
# **Questions:**
# 1. Did the equally-weighted portfolio outperform or underperform the S&P 500?
# 2. Is higher return always better? What else should you consider?
# 3. What would happen if you changed the weights to 50% AAPL, 25% MSFT, 25% JPM?
#
# **Your answers:**
# 1.
# 2.
# 3.

# %% [markdown]
# ---
# # 🔥 Challenge — Rolling Beta & Risk-Return Plot
#
# **Challenge A:** Compute a rolling 6-month beta for AAPL and plot how it changes over time.
#
# **Challenge B:** Create a risk-return scatter plot for 10+ stocks (x = annual vol, y = annual return).

# %%
# Challenge A: Rolling Beta
# WINDOW = 126  # ~6 months
# YOUR CODE HERE

# %%
# Challenge B: Risk-Return Plot
# universe = ['AAPL','MSFT','JPM','TSLA','NVDA','JNJ','XOM','AMZN','META','GS','^GSPC']
# YOUR CODE HERE

# %% [markdown]
# ---
# *Applied Statistical Data Analysis | Prof. Dr. Kristyna Ters | FHNW School of Business | HS 2026*
#
# *Solutions will be released after the submission deadline.*
